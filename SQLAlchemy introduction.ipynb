# %% [markdown]
# # Introduction to SQLAlchemy

# %% [markdown]
# - __0.__ Introduction
# - __1.__ Importing necessary libraries
# - __2.__ Creating engine
# - __3.__ Creating the connection
# - __4.__ Inspecting the database
# - __5.__ Querying the database
# - __6.__ Read a View to DataFrame
# - __7.__ Example of Using a CTE
# - __8.__ Create a New Table from DataFrame
# - __9.__ Delete a table
# - __10.__ Workflow example

# %% [markdown]
# ## 0. Introduction
# SQLAlchemy is a library that facilitates communication between Python programs and databases.
#
# There are two ways of working with SQLAlchemy:
# - SQLAlchemy Core: the foundational architecture for SQLAlchemy as a “database toolkit”. It provides tools for managing connectivity to a database, interacting with database queries and results, and construction of SQL statements
# - SQLAlchemy ORM:  builds upon the Core to provide optional object-relational mapping capabilities as it represents database relations as Python objects.
#
# In this course, we will focus on the SQLAlchemy Core architecture, which gives us the following advantages:
# - Learning the basic concepts in SQLAlchemy
# - practicing the use of the Pandas library
# - practicing the use of SQL statements

# %%
# !pip install sqlalchemy
# !pip install pyodbc
# Out:
# Requirement already satisfied: sqlalchemy in c:\python311\lib\site-packages (2.0.23)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\python311\lib\site-packages (from sqlalchemy) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\python311\lib\site-packages (from sqlalchemy) (3.0.2)
# Requirement already satisfied: pyodbc in c:\python311\lib\site-packages (5.0.1)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1. Importing necessary libraries

# %%
from sqlalchemy import create_engine, Table, inspect
import pandas as pd

# %% [markdown]
# ## 2. Creating engine
#
# In order to connect to a database, first we need to create an engine. The engine references are:
# - a __Dialect__: There are several types of RDBMS, which we call dialects in SQLAlchemy. They all use SQL as a base, but they have slight differences. \
# The most common RDBMS are: MSSQL, MySQL, PostgreSQL, Oracle, SQLite. \
# Each dialect in SQLAlchemy has a standard DBAPI, which serves as a bridge between Python programs and the relational databases, and they standardize the way to perform database operations.
# - a __Pool__: a pool will establish a connection at the specified server location
# - a __Database__: the database name we want to connect to
# - __username__ and __password__: when using SQL Server identication, we need to provide the username and password to be able to connect to the database. When using the Microsoft Authentication method, the username and password is not required, as the user is automatically identified by the Microsoft signin credentials.
#
# __NOTE__: by creating an engine, we did not yet connect to the database, we simply gave the instructions of how and where to connect.

# %%
def new_engine(dialect, server, database, user=None, password=None, integrated_security=True):
    if integrated_security:
        # For Windows authentication
        eng = f"{dialect}://{server}/{database}?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server"
    else:
        assert user, 'You must define a username'
        assert password, 'You must define a password'
        # For SQL Server authentication
        eng = f"{dialect}://{user}:{password}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server"
    print(eng)
    return create_engine(eng)

# %%
# For Windows authentication
# Replace the server argument with the Server Name found when logging into SQL Server Management Studio 
# OR
# For SQL Server authentication
# Replace the server, user and password argument with the Server Name, username and password
engine = new_engine('mssql', 'DESKTOP-CIKOHBH', 'AdventureWorks2022')
# Out:
# mssql://DESKTOP-CIKOHBH/AdventureWorks2022?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server

# %%
# create_engine("mssql://DESKTOP-CIKOHBH/AdventureWorks2022?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server")

# %%
print(type(engine))
# Out:
# <class 'sqlalchemy.engine.base.Engine'>

# %% [markdown]
# ## 3. Creating the connection
#
# The engine class instance we created has the .connect() method, which returns a Connection object and technically creates the connection between the database and our Python application.

# %%
connection = engine.connect()

# %%
print(type(connection))
# Out:
# <class 'sqlalchemy.engine.base.Connection'>

# %% [markdown]
# ## 4. Inspecting the database
#
# Now that we have a connection to the database, we can inspect its contents. \
# The AdventureWorks database has multiple schemas which we can list with the following command.

# %%
inspector = inspect(engine)
schemas = inspector.get_schema_names()
print(schemas)
# Out:
# ['db_accessadmin', 'db_backupoperator', 'db_datareader', 'db_datawriter', 'db_ddladmin', 'db_denydatareader', 'db_denydatawriter', 'db_owner', 'db_securityadmin', 'dbo', 'guest', 'HumanResources', 'INFORMATION_SCHEMA', 'Person', 'Production', 'Purchasing', 'Sales', 'sys']

# %%
for schema in schemas:
    print(schema)
# Out:
# db_accessadmin
# db_backupoperator
# db_datareader
# db_datawriter
# db_ddladmin
# db_denydatareader
# db_denydatawriter
# db_owner
# db_securityadmin
# dbo
# guest
# HumanResources
# INFORMATION_SCHEMA
# Person
# Production
# Purchasing
# Sales
# sys

# %% [markdown]
# Each schema in the database logically groups together tables, views, indexes and procedures. Schemas also help with security, as we can grant permission for users into specific schemas. \
# In this example we list all the available tables in the Sales schema. All these tables are related to sales or the sales department.

# %%
print(inspector.get_table_names(schema='Sales'))
# Out:
# ['August_Goal_Table', 'CountryRegionCurrency', 'CreditCard', 'Currency', 'CurrencyRate', 'Customer', 'MontyPython', 'PersonCreditCard', 'SalesOrderDetail', 'SalesOrderHeader', 'SalesOrderHeaderSalesReason', 'SalesPerson', 'SalesPersonQuotaHistory', 'SalesReason', 'SalesTaxRate', 'SalesTerritory', 'SalesTerritoryHistory', 'ShoppingCartItem', 'SpecialOffer', 'SpecialOfferProduct', 'Store']

# %%
for col in inspector.get_columns(table_name='Customer', schema='Sales'):
#     print(col)
    print(col['name'])
# Out:
# CustomerID
# PersonID
# StoreID
# TerritoryID
# AccountNumber
# rowguid
# ModifiedDate

# %% [markdown]
# ## 5. Querying the database
#
# The Pandas library can directly connect to and query a database with the .read_sql() method. The two most important arguments of the method are:
# - sql: this is the SQL command that the query will execute
# - con: the connection we defined to the database
#
# The result is a Pandas DataFrame.

# %%
df = pd.read_sql(sql="SELECT * from Sales.Customer", con=connection)

# %%
df.head(12)
# Out:
#     CustomerID  PersonID  StoreID  TerritoryID AccountNumber  \
# 0            1       NaN    934.0            1    AW00000001
# 1            2       NaN   1028.0            1    AW00000002
# 2            3       NaN    642.0            4    AW00000003
# 3            4       NaN    932.0            4    AW00000004
# 4            5       NaN   1026.0            4    AW00000005
# 5            6       NaN    644.0            4    AW00000006
# 6            7       NaN    930.0            1    AW00000007
# 7            8       NaN   1024.0            5    AW00000008
# 8            9       NaN    620.0            5    AW00000009
# 9           10       NaN    928.0            6    AW00000010
# 10          11       NaN   1022.0            6    AW00000011
# 11          12       NaN    622.0            6    AW00000012
#
#                                  rowguid            ModifiedDate
# 0   3F5AE95E-B87D-4AED-95B4-C3797AFCB74F 2014-09-12 11:15:07.263
# 1   E552F657-A9AF-4A7D-A645-C429D6E02491 2014-09-12 11:15:07.263
# 2   130774B1-DB21-4EF3-98C8-C104BCD6ED6D 2014-09-12 11:15:07.263
# 3   FF862851-1DAA-4044-BE7C-3E85583C054D 2014-09-12 11:15:07.263
# 4   83905BDC-6F5E-4F71-B162-C98DA069F38A 2014-09-12 11:15:07.263
# 5   1A92DF88-BFA2-467D-BD54-FCB9E647FDD7 2014-09-12 11:15:07.263
# 6   03E9273E-B193-448E-9823-FE0C44AEED78 2014-09-12 11:15:07.263
# 7   801368B1-4323-4BFA-8BEA-5B5B1E4BD4A0 2014-09-12 11:15:07.263
# 8   B900BB7F-23C3-481D-80DA-C49A5BD6F772 2014-09-12 11:15:07.263
# 9   CDB6698D-2FF1-4FBA-8F22-60AD1D11DABD 2014-09-12 11:15:07.263
# 10  750F3495-59C4-48A0-80E1-E37EC60E77D9 2014-09-12 11:15:07.263
# 11  947BCAF1-1F32-44F3-B9C3-0011F95FBE54 2014-09-12 11:15:07.263

# %% [markdown]
# The SQL query can get as complex as the user wants.\
# Here is an example of multiple JOIN statements

# %%
multijoin_sql ="""
SELECT
  c.CustomerID, 
  c.StoreID, 
  c.AccountNumber, 
  soh.SalesOrderID, 
  sod.ProductID
FROM Sales.Customer AS c 
INNER JOIN Sales.SalesOrderHeader AS soh 
    ON c.CustomerID = soh.CustomerID
INNER JOIN Sales.SalesOrderDetail AS sod 
    ON soh.SalesOrderID = sod.SalesOrderID
"""
join_df = pd.read_sql(sql=multijoin_sql, con=connection)

# %%
join_df.head()
# Out:
#    CustomerID  StoreID AccountNumber  SalesOrderID  ProductID
# 0       29580    518.0    AW00029580         43665        707
# 1       29614    592.0    AW00029614         43668        707
# 2       29844   1086.0    AW00029844         43673        707
# 3       29824   1044.0    AW00029824         43677        707
# 4       29889   1184.0    AW00029889         43678        707

# %% [markdown]
# ## 6. Read a View to DataFrame
# Reading in Views into a DataFrame is the exact same process as reading the tables, we just need to specify which view to read

# %%
view_sql = """
SELECT * 
FROM HumanResources.vEmployee
"""

view = pd.read_sql(sql=view_sql, con=connection)

# %%
view.head()
# Out:
#    BusinessEntityID Title FirstName MiddleName      LastName Suffix  \
# 0               278  None   Garrett          R        Vargas   None
# 1               279  None      Tsvi    Michael        Reiter   None
# 2               280  None    Pamela          O  Ansman-Wolfe   None
# 3               252  None    Arvind          B           Rao   None
# 4               251  None    Mikael          Q      Sandberg   None
#
#                JobTitle   PhoneNumber PhoneNumberType  \
# 0  Sales Representative  922-555-0165            Work
# 1  Sales Representative  664-555-0112            Work
# 2  Sales Representative  340-555-0193            Cell
# 3                 Buyer  848-555-0163            Cell
# 4                 Buyer  309-555-0170            Work
#
#                    EmailAddress  EmailPromotion         AddressLine1  \
# 0  garrett1@adventure-works.com               0   10203 Acorn Avenue
# 1     tsvi0@adventure-works.com               1    8291 Crossbow Way
# 2   pamela0@adventure-works.com               1    636 Vine Hill Way
# 3   arvind0@adventure-works.com               0  9495 Limewood Place
# 4   mikael0@adventure-works.com               2     9539 Glenside Dr
#
#   AddressLine2      City StateProvinceName PostalCode CountryRegionName  \
# 0         None   Calgary           Alberta    T2P 2G8            Canada
# 1         None   Memphis         Tennessee      38103     United States
# 2         None  Portland            Oregon      97205     United States
# 3         None    Renton        Washington      98055     United States
# 4         None   Bothell        Washington      98011     United States
#
#   AdditionalContactInfo
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None

# %% [markdown]
# ## 7. Example of Using a CTE (Common Table Expression)
# Common Table Expressions are a great tool for managing more complex queries.\
# Basically we create intermediate temporary tables, which we use later in further queries.

# %%
pd.read_sql("""SELECT 
    P.BusinessEntityID, 
    P.FirstName, 
    P.LastName, 
    HR.JobTitle 
  FROM HumanResources.Employee AS HR 
  INNER JOIN Person.Person AS P 
      ON HR.BusinessEntityID = P.BusinessEntityID 
  WHERE 
    Gender = 'M'""", con=connection)

# %%
cte_sql = """
WITH CTE_Employee AS (
  SELECT 
    P.BusinessEntityID, 
    P.FirstName, 
    P.LastName, 
    HR.JobTitle 
  FROM HumanResources.Employee AS HR 
  INNER JOIN Person.Person AS P 
      ON HR.BusinessEntityID = P.BusinessEntityID 
  WHERE 
    Gender = 'M'
) 
SELECT 
  CTE_Employee.BusinessEntityID, 
  CTE_Employee.FirstName, 
  CTE_Employee.LastName, 
  CTE_Employee.JobTitle, 
  SUM(Sales.SubTotal) TotalSum 
FROM CTE_Employee 
INNER JOIN Sales.SalesOrderHeader AS Sales 
    ON CTE_Employee.BusinessEntityID = Sales.SalesPersonID 
GROUP BY 
  CTE_Employee.BusinessEntityID, 
  CTE_Employee.FirstName, 
  CTE_Employee.LastName, 
  CTE_Employee.JobTitle 
ORDER BY
  CTE_Employee.BusinessEntityID;

"""

result = pd.read_sql(cte_sql, engine)
result
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near ';'. (102) (SQLExecDirectW)")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[11], line 33
#       1 cte_sql = """
#       2 WITH CTE_Employee AS (
#       3   SELECT
#    (...)
#      30
#      31 """
# ---> 33 result = pd.read_sql(cte_sql, engine)
#      34 result
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\pandas\io\sql.py:682, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     672     return pandas_sql.read_table(
#     673         sql,
#     674         index_col=index_col,
#    (...)
#     679         dtype_backend=dtype_backend,
#     680     )
#     681 else:
# --> 682     return pandas_sql.read_query(
#     683         sql,
#     684         index_col=index_col,
#     685         params=params,
#     686         coerce_float=coerce_float,
#     687         parse_dates=parse_dates,
#     688         chunksize=chunksize,
#     689         dtype_backend=dtype_backend,
#     690         dtype=dtype,
#     691     )
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\pandas\io\sql.py:1776, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1719 def read_query(
#    1720     self,
#    1721     sql: str,
#    (...)
#    1728     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1729 ) -> DataFrame | Iterator[DataFrame]:
#    1730     """
#    1731     Read SQL query into a DataFrame.
#    1732
#    (...)
#    1774
#    1775     """
# -> 1776     result = self.execute(sql, params)
#    1777     columns = result.keys()
#    1779     if chunksize is not None:
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\pandas\io\sql.py:1599, in SQLDatabase.execute(self, sql, params)
#    1597 args = [] if params is None else [params]
#    1598 if isinstance(sql, str):
# -> 1599     return self.con.exec_driver_sql(sql, *args)
#    1600 return self.con.execute(sql, *args)
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:1778, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1773 execution_options = self._execution_options.merge_with(
#    1774     execution_options
#    1775 )
#    1777 dialect = self.dialect
# -> 1778 ret = self._execute_context(
#    1779     dialect,
#    1780     dialect.execution_ctx_cls._init_statement,
#    1781     statement,
#    1782     None,
#    1783     execution_options,
#    1784     statement,
#    1785     distilled_parameters,
#    1786 )
#    1788 return ret
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:2343, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2341 elif should_wrap:
#    2342     assert sqlalchemy_exception is not None
# -> 2343     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2344 else:
#    2345     assert exc_info[1] is not None
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)
#    1980         context.executemany,
#    1981     )
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# ProgrammingError: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near ';'. (102) (SQLExecDirectW)")
# [SQL:
# WITH CTE_Employee AS (
#   SELECT
#     P.BusinessEntityID,
#     P.FirstName,
#     P.LastName,
#     HR.JobTitle
#   FROM HumanResources.Employee AS HR
#   INNER JOIN Person.Person AS P
#       ON HR.BusinessEntityID = P.BusinessEntityID
#   WHERE
#     Gender = 'M'
# )
# SELECT
#   CTE_Employee.BusinessEntityID,
#   CTE_Employee.FirstName,
#   CTE_Employee.LastName,
#   CTE_Employee.JobTitle,
#   SUM(Sales.SubTotal) TotalSum
# FROM CTE_Employee
# INNER JOIN Sales.SalesOrderHeader AS Sales
#     ON CTE_Employee.BusinessEntityID = Sales.SalesPersonID
# GROUP BY
#   CTE_Employee.BusinessEntityID,
#   CTE_Employee.FirstName,
#   CTE_Employee.LastName,
#   CTE_Employee.JobTitle
# ORDER BY ;
#   CTE_Employee.BusinessEntityID;
#
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
test_sql = """
SELECT  
FROM HumanResources.Employee
"""


test_df = pd.read_sql(sql=test_sql, con=connection)
test_df.head()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\cursor.py:1135, in CursorFetchStrategy.fetchall(self, result, dbapi_cursor)
#    1134 try:
# -> 1135     rows = dbapi_cursor.fetchall()
#    1136     result._soft_close()
#
# ProgrammingError: ('ODBC SQL type -151 is not yet supported.  column-index=3  type=-151', 'HY106')
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[45], line 10
#       1 test_sql = """
#       2 SELECT *
#       3 FROM HumanResources.Employee
#       4 """
#       5 view_sql = """
#       6 SELECT *
#       7 FROM HumanResources.vEmployee
#       8 """
# ---> 10 test_df = pd.read_sql(sql=test_sql, con=connection)
#      11 test_df.head()
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\pandas\io\sql.py:682, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     672     return pandas_sql.read_table(
#     673         sql,
#     674         index_col=index_col,
#    (...)
#     679         dtype_backend=dtype_backend,
#     680     )
#     681 else:
# --> 682     return pandas_sql.read_query(
#     683         sql,
#     684         index_col=index_col,
#     685         params=params,
#     686         coerce_float=coerce_float,
#     687         parse_dates=parse_dates,
#     688         chunksize=chunksize,
#     689         dtype_backend=dtype_backend,
#     690         dtype=dtype,
#     691     )
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\pandas\io\sql.py:1793, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1781     return self._query_iterator(
#    1782         result,
#    1783         self.exit_stack,
#    (...)
#    1790         dtype_backend=dtype_backend,
#    1791     )
#    1792 else:
# -> 1793     data = result.fetchall()
#    1794     frame = _wrap_result(
#    1795         data,
#    1796         columns,
#    (...)
#    1801         dtype_backend=dtype_backend,
#    1802     )
#    1803     return frame
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\result.py:1328, in Result.fetchall(self)
#    1325 def fetchall(self) -> Sequence[Row[_TP]]:
#    1326     """A synonym for the :meth:`_engine.Result.all` method."""
# -> 1328     return self._allrows()
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\result.py:554, in ResultInternal._allrows(self)
#     550 post_creational_filter = self._post_creational_filter
#     552 make_row = self._row_getter
# --> 554 rows = self._fetchall_impl()
#     555 made_rows: List[_InterimRowType[_R]]
#     556 if make_row:
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\cursor.py:2102, in CursorResult._fetchall_impl(self)
#    2101 def _fetchall_impl(self):
# -> 2102     return self.cursor_strategy.fetchall(self, self.cursor)
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\cursor.py:1139, in CursorFetchStrategy.fetchall(self, result, dbapi_cursor)
#    1137     return rows
#    1138 except BaseException as e:
# -> 1139     self.handle_exception(result, dbapi_cursor, e)
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\cursor.py:1080, in CursorFetchStrategy.handle_exception(self, result, dbapi_cursor, err)
#    1074 def handle_exception(
#    1075     self,
#    1076     result: CursorResult[Any],
#    1077     dbapi_cursor: Optional[DBAPICursor],
#    1078     err: BaseException,
#    1079 ) -> NoReturn:
# -> 1080     result.connection._handle_dbapi_exception(
#    1081         err, None, None, dbapi_cursor, result.context
#    1082     )
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:2343, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2341 elif should_wrap:
#    2342     assert sqlalchemy_exception is not None
# -> 2343     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2344 else:
#    2345     assert exc_info[1] is not None
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\cursor.py:1135, in CursorFetchStrategy.fetchall(self, result, dbapi_cursor)
#    1129 def fetchall(
#    1130     self,
#    1131     result: CursorResult[Any],
#    1132     dbapi_cursor: DBAPICursor,
#    1133 ) -> Any:
#    1134     try:
# -> 1135         rows = dbapi_cursor.fetchall()
#    1136         result._soft_close()
#    1137         return rows
#
# ProgrammingError: (pyodbc.ProgrammingError) ('ODBC SQL type -151 is not yet supported.  column-index=3  type=-151', 'HY106')
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## 8. Create a New Table from DataFrame
# Creating new tables and adding them to our database is straightforward. \
# We create/define our DataFrame and then we use the pandas.to_sql() method. \
# We must define:
# - the __name__ of the table
# - the connection we are using (__con__)
# - the __schema__ we want to create the table in (if not provided the table will be added the the default dbo schema)
# - if we want to have a separate index column or keep the columns as is (__index__)
# - what SQLAlchemy should do if the table already exists (__if_exists__)

# %%
table_data = {'Sketch':['Cheese shop sketch', 'Silly walks', 'Spanish inquisition', 'Lumberjack song', 'Argument clinic'],
        'Length':['5:29', '4:05', '8:17', '2:41', '6:22']
       }

df2 = pd.DataFrame(data=table_data)
df2
# Out:
#                 Sketch Length
# 0   Cheese shop sketch   5:29
# 1          Silly walks   4:05
# 2  Spanish inquisition   8:17
# 3      Lumberjack song   2:41
# 4      Argument clinic   6:22

# %%
df2.to_sql(name='MontyPython', con=engine, schema='Sales', index=False, if_exists='replace')
# Out:
# 5

# %%
# Save the table into the default dbo schema. dbo stands for DataBase Owner
df2.to_sql(name='MontyPython', con=engine, index=False, if_exists='replace')
# Out:
# 5

# %% [markdown]
# ## 9. Delete a table

# %%
# Reading the table / Check existence
pd.read_sql("SELECT * FROM Sales.MontyPython", engine)
# Out:
#                 Sketch Length
# 0   Cheese shop sketch   5:29
# 1          Silly walks   4:05
# 2  Spanish inquisition   8:17
# 3      Lumberjack song   2:41
# 4      Argument clinic   6:22

# %%
# Executing the DROP TABLE command in Pandas
from pandas.io import sql
sql.execute('DROP TABLE IF EXISTS Person.Person', connection)
# Out:
# C:\Users\marke\AppData\Local\Temp\ipykernel_14300\3253862291.py:3: FutureWarning: `pandas.io.sql.execute` is deprecated and will be removed in the future version.
#   sql.execute('DROP TABLE IF EXISTS Person.Person', connection)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Could not drop object 'Person.Person' because it is referenced by a FOREIGN KEY constraint. (3726) (SQLExecDirectW)")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Executing the DROP TABLE command in Pandas
#       2 from pandas.io import sql
# ----> 3 sql.execute('DROP TABLE IF EXISTS Person.Person', connection)
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\pandas\io\sql.py:225, in execute(sql, con, params)
#     223     raise TypeError("pandas.io.sql.execute requires a connection")  # GH50185
#     224 with pandasSQL_builder(con, need_transaction=True) as pandas_sql:
# --> 225     return pandas_sql.execute(sql, params)
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\pandas\io\sql.py:1599, in SQLDatabase.execute(self, sql, params)
#    1597 args = [] if params is None else [params]
#    1598 if isinstance(sql, str):
# -> 1599     return self.con.exec_driver_sql(sql, *args)
#    1600 return self.con.execute(sql, *args)
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:1778, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1773 execution_options = self._execution_options.merge_with(
#    1774     execution_options
#    1775 )
#    1777 dialect = self.dialect
# -> 1778 ret = self._execute_context(
#    1779     dialect,
#    1780     dialect.execution_ctx_cls._init_statement,
#    1781     statement,
#    1782     None,
#    1783     execution_options,
#    1784     statement,
#    1785     distilled_parameters,
#    1786 )
#    1788 return ret
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:1848, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
# -> 1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:1988, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985     result = context._setup_result_proxy()
#    1987 except BaseException as e:
# -> 1988     self._handle_dbapi_exception(
#    1989         e, str_statement, effective_parameters, cursor, context
#    1990     )
#    1992 return result
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:2343, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2341 elif should_wrap:
#    2342     assert sqlalchemy_exception is not None
# -> 2343     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2344 else:
#    2345     assert exc_info[1] is not None
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\base.py:1969, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1967                 break
#    1968     if not evt_handled:
# -> 1969         self.dialect.do_execute(
#    1970             cursor, str_statement, effective_parameters, context
#    1971         )
#    1973 if self._has_events or self.engine._has_events:
#    1974     self.dispatch.after_cursor_execute(
#    1975         self,
#    1976         cursor,
#    (...)
#    1980         context.executemany,
#    1981     )
#
# File D:\#teach\SQL\#coding_ground\sql\Lib\site-packages\sqlalchemy\engine\default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# ProgrammingError: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Could not drop object 'Person.Person' because it is referenced by a FOREIGN KEY constraint. (3726) (SQLExecDirectW)")
# [SQL: DROP TABLE IF EXISTS Person.Person]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# Reading the table / Check existence
pd.read_sql("SELECT * FROM Sales.MontyPython", engine)

# %% [markdown]
# ## 10. Workflow example
# In this part, we will go through an example of a workflow:
# - Read: reading in data from the database into a Pandas DataFrame
# - Update: modifying the data in the DataFrame
# - Save: saving the modified DataFrame into a new database table

# %% [markdown]
# #### Reading in data

# %%
# Read: reading in data from the database into a Pandas DataFrame
# Products ranked based on sold amount between 2011-07-01 and 2011-08-01
example_sql ="""
SELECT 
  DENSE_RANK() OVER (ORDER BY SUM(SOD.OrderQty) DESC) AS SalesRank,
  P.ProductID,
  P.Name,
  SUM(SOD.OrderQty) AS TotalSold
FROM 
  Production.Product AS P 
  JOIN Sales.SalesOrderDetail AS SOD ON P.ProductID = SOD.ProductID 
  JOIN Sales.SalesOrderHeader AS SOH ON SOD.SalesOrderID = SOH.SalesOrderID
WHERE 
  SOH.OrderDate BETWEEN '2011-07-01' AND '2011-07-31'
GROUP BY
  P.ProductID, P.Name
ORDER BY
  SUM(SOD.OrderQty) DESC
"""

example_df = pd.read_sql(example_sql, engine, index_col='SalesRank')
example_df
# Out:
#            ProductID                            Name  TotalSold
# SalesRank
# 1                709          Mountain Bike Socks, M        134
# 2                715      Long-Sleeve Logo Jersey, L        114
# 3                712                    AWC Logo Cap        103
# 4                770              Road-650 Black, 52         88
# 5                771         Mountain-100 Silver, 38         81
# 5                776          Mountain-100 Black, 42         81
# 6                758                Road-450 Red, 52         72
# 7                775          Mountain-100 Black, 38         71
# 7                760                Road-650 Red, 60         71
# 8                777          Mountain-100 Black, 44         66
# 9                778          Mountain-100 Black, 48         64
# 9                762                Road-650 Red, 44         64
# 9                711          Sport-100 Helmet, Blue         64
# 10               753                Road-150 Red, 56         61
# 10               761                Road-650 Red, 62         61
# 11               707           Sport-100 Helmet, Red         58
# 12               772         Mountain-100 Silver, 42         57
# 12               773         Mountain-100 Silver, 44         57
# 13               708         Sport-100 Helmet, Black         56
# 14               754                Road-450 Red, 58         54
# 14               763                Road-650 Red, 48         54
# 15               716     Long-Sleeve Logo Jersey, XL         48
# 16               765              Road-650 Black, 58         47
# 17               774         Mountain-100 Silver, 48         42
# 18               729         LL Road Frame - Red, 60         41
# 18               749                Road-150 Red, 62         41
# 19               738       LL Road Frame - Black, 52         39
# 20               725         LL Road Frame - Red, 44         38
# 21               714      Long-Sleeve Logo Jersey, M         37
# 22               732         ML Road Frame - Red, 48         26
# 23               755                Road-450 Red, 60         22
# 24               756                Road-450 Red, 44         21
# 24               752                Road-150 Red, 52         21
# 25               748  HL Mountain Frame - Silver, 38         20
# 25               722       LL Road Frame - Black, 58         20
# 26               726         LL Road Frame - Red, 48         19
# 26               745   HL Mountain Frame - Black, 48         19
# 26               768              Road-650 Black, 44         19
# 27               751                Road-150 Red, 48         18
# 28               766              Road-650 Black, 60         17
# 29               764                Road-650 Red, 52         15
# 29               742  HL Mountain Frame - Silver, 46         15
# 29               750                Road-150 Red, 44         15
# 30               747   HL Mountain Frame - Black, 38         14
# 30               741  HL Mountain Frame - Silver, 48         14
# 31               730         LL Road Frame - Red, 62         13
# 31               710          Mountain Bike Socks, L         13
# 31               743   HL Mountain Frame - Black, 42         13
# 32               733         ML Road Frame - Red, 52          8
# 33               767              Road-650 Black, 62          2
# 34               759                Road-650 Red, 58          1

# %% [markdown]
# #### Modifying the DataFrame

# %%
# Update: modifying the data in the DataFrame
# Adding a Goal column to th DataFrame, with the next month (August) sales goal of +10% TotalSold
example_df['August_Goal'] = round(example_df['TotalSold'] * 1.1, 0).astype(int)
example_df
# Out:
#            ProductID                            Name  TotalSold  August_Goal
# SalesRank
# 1                709          Mountain Bike Socks, M        134          147
# 2                715      Long-Sleeve Logo Jersey, L        114          125
# 3                712                    AWC Logo Cap        103          113
# 4                770              Road-650 Black, 52         88           97
# 5                771         Mountain-100 Silver, 38         81           89
# 5                776          Mountain-100 Black, 42         81           89
# 6                758                Road-450 Red, 52         72           79
# 7                775          Mountain-100 Black, 38         71           78
# 7                760                Road-650 Red, 60         71           78
# 8                777          Mountain-100 Black, 44         66           73
# 9                778          Mountain-100 Black, 48         64           70
# 9                762                Road-650 Red, 44         64           70
# 9                711          Sport-100 Helmet, Blue         64           70
# 10               753                Road-150 Red, 56         61           67
# 10               761                Road-650 Red, 62         61           67
# 11               707           Sport-100 Helmet, Red         58           64
# 12               772         Mountain-100 Silver, 42         57           63
# 12               773         Mountain-100 Silver, 44         57           63
# 13               708         Sport-100 Helmet, Black         56           62
# 14               754                Road-450 Red, 58         54           59
# 14               763                Road-650 Red, 48         54           59
# 15               716     Long-Sleeve Logo Jersey, XL         48           53
# 16               765              Road-650 Black, 58         47           52
# 17               774         Mountain-100 Silver, 48         42           46
# 18               729         LL Road Frame - Red, 60         41           45
# 18               749                Road-150 Red, 62         41           45
# 19               738       LL Road Frame - Black, 52         39           43
# 20               725         LL Road Frame - Red, 44         38           42
# 21               714      Long-Sleeve Logo Jersey, M         37           41
# 22               732         ML Road Frame - Red, 48         26           29
# 23               755                Road-450 Red, 60         22           24
# 24               756                Road-450 Red, 44         21           23
# 24               752                Road-150 Red, 52         21           23
# 25               748  HL Mountain Frame - Silver, 38         20           22
# 25               722       LL Road Frame - Black, 58         20           22
# 26               726         LL Road Frame - Red, 48         19           21
# 26               745   HL Mountain Frame - Black, 48         19           21
# 26               768              Road-650 Black, 44         19           21
# 27               751                Road-150 Red, 48         18           20
# 28               766              Road-650 Black, 60         17           19
# 29               764                Road-650 Red, 52         15           16
# 29               742  HL Mountain Frame - Silver, 46         15           16
# 29               750                Road-150 Red, 44         15           16
# 30               747   HL Mountain Frame - Black, 38         14           15
# 30               741  HL Mountain Frame - Silver, 48         14           15
# 31               730         LL Road Frame - Red, 62         13           14
# 31               710          Mountain Bike Socks, L         13           14
# 31               743   HL Mountain Frame - Black, 42         13           14
# 32               733         ML Road Frame - Red, 52          8            9
# 33               767              Road-650 Black, 62          2            2
# 34               759                Road-650 Red, 58          1            1

# %% [markdown]
# #### Saving the modified DataFrame

# %%
# Save: saving the modified DataFrame into a new database table
example_df.to_sql(name='August_Goal_Table', con=engine, schema='Sales', index=False, if_exists='replace')
# Out:
# 51

# %% [markdown]
# #### Controlling the result

# %%
# Double checking if the new table was created
check = pd.read_sql('SELECT * FROM Sales.August_Goal_Table', engine)
check
# Out:
#     ProductID                            Name  TotalSold  August_Goal
# 0         709          Mountain Bike Socks, M        134          147
# 1         715      Long-Sleeve Logo Jersey, L        114          125
# 2         712                    AWC Logo Cap        103          113
# 3         770              Road-650 Black, 52         88           97
# 4         771         Mountain-100 Silver, 38         81           89
# 5         776          Mountain-100 Black, 42         81           89
# 6         758                Road-450 Red, 52         72           79
# 7         775          Mountain-100 Black, 38         71           78
# 8         760                Road-650 Red, 60         71           78
# 9         777          Mountain-100 Black, 44         66           73
# 10        778          Mountain-100 Black, 48         64           70
# 11        762                Road-650 Red, 44         64           70
# 12        711          Sport-100 Helmet, Blue         64           70
# 13        753                Road-150 Red, 56         61           67
# 14        761                Road-650 Red, 62         61           67
# 15        707           Sport-100 Helmet, Red         58           64
# 16        772         Mountain-100 Silver, 42         57           63
# 17        773         Mountain-100 Silver, 44         57           63
# 18        708         Sport-100 Helmet, Black         56           62
# 19        754                Road-450 Red, 58         54           59
# 20        763                Road-650 Red, 48         54           59
# 21        716     Long-Sleeve Logo Jersey, XL         48           53
# 22        765              Road-650 Black, 58         47           52
# 23        774         Mountain-100 Silver, 48         42           46
# 24        729         LL Road Frame - Red, 60         41           45
# 25        749                Road-150 Red, 62         41           45
# 26        738       LL Road Frame - Black, 52         39           43
# 27        725         LL Road Frame - Red, 44         38           42
# 28        714      Long-Sleeve Logo Jersey, M         37           41
# 29        732         ML Road Frame - Red, 48         26           29
# 30        755                Road-450 Red, 60         22           24
# 31        756                Road-450 Red, 44         21           23
# 32        752                Road-150 Red, 52         21           23
# 33        748  HL Mountain Frame - Silver, 38         20           22
# 34        722       LL Road Frame - Black, 58         20           22
# 35        726         LL Road Frame - Red, 48         19           21
# 36        745   HL Mountain Frame - Black, 48         19           21
# 37        768              Road-650 Black, 44         19           21
# 38        751                Road-150 Red, 48         18           20
# 39        766              Road-650 Black, 60         17           19
# 40        764                Road-650 Red, 52         15           16
# 41        742  HL Mountain Frame - Silver, 46         15           16
# 42        750                Road-150 Red, 44         15           16
# 43        747   HL Mountain Frame - Black, 38         14           15
# 44        741  HL Mountain Frame - Silver, 48         14           15
# 45        730         LL Road Frame - Red, 62         13           14
# 46        710          Mountain Bike Socks, L         13           14
# 47        743   HL Mountain Frame - Black, 42         13           14
# 48        733         ML Road Frame - Red, 52          8            9
# 49        767              Road-650 Black, 62          2            2
# 50        759                Road-650 Red, 58          1            1
